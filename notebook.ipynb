# %% [markdown]
# ##First
#
# 1. Reading the data from CSV file
# 2. Training the model
# 3. Saving the model into a file

# %%
import pandas as pd
import numpy as np
import os
print(os.getcwd())
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, InputLayer
import pickle

# loading the data from CSV file
file_path = 'GOOG.csv'
df = pd.read_csv(file_path)

# handling missing values
df = df.dropna()

# Select features (X) and target variable (y)
features = ['Open', 'High', 'Low', 'Close', 'Volume']


target = 'Close' #The target variable (y) is the Close price, which the model aims to predict. 

X = df[features]
y = df[target] 

# normalizing the features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Splitting the data into training and testing sets, will use 20%, 80% split
X_train, X_test, y_train, y_test, date_train, date_test = train_test_split(X_scaled, y, df['Date'], test_size=0.2, random_state=42)

# building the LSTM model
model = Sequential()
model.add(InputLayer(shape=(X_train.shape[1], 1)))
model.add(LSTM(units=50, activation='relu'))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# reshaping the data for LSTM input
X_train_lstm = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_lstm = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# number of epochs
number_epochs = 100

# training the model
model.fit(X_train_lstm, y_train, epochs=number_epochs, batch_size=32, verbose=2)

# saving the model in native Keras format
model.save(f'stock_price_prediction_model_{number_epochs}_epochs.keras')

# Save the scaler
with open(f'scaler_{number_epochs}_epochs.pkl', 'wb') as f:
    pickle.dump(scaler, f)

print("Scaler saved successfully as scaler.pkl.")

print(f'\n\nModel saved successfully with {number_epochs} epochs!')
# Out:
# e:\Stock-Price-Prediction-Using-AI-and-Machine-Learning-main
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 7
#       5 from sklearn.model_selection import train_test_split
#       6 from sklearn.preprocessing import MinMaxScaler
# ----> 7 from tensorflow.keras.models import Sequential
#       8 from tensorflow.keras.layers import Dense, LSTM, InputLayer
#       9 import pickle
#
# ModuleNotFoundError: No module named 'tensorflow'

# %% [markdown]
# Second
#
# 1. Loading previously saved model
# 2. Loading data again
# 3. Predicting prices

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import load_model

# loading the data for prediction from CSV file
file_path = 'GOOG.csv'
df_new = pd.read_csv(file_path)

# handling missing values
df_new = df_new.dropna()

# selecting features (X) for prediction
X_new = df_new[features]

# normalizing the features using the same scaler from training
X_scaled_new = scaler.transform(X_new)

# reshaping the data for LSTM input
X_new_lstm = X_scaled_new.reshape((X_scaled_new.shape[0], X_scaled_new.shape[1], 1))

# setting epochs
number_epochs = 100

# loading the saved model with number_epochs
loaded_model = load_model(f'stock_price_prediction_model_{number_epochs}_epochs.keras')

# making predictions
predictions = loaded_model.predict(X_new_lstm)

# creating a DataFrame with the predictions and corresponding dates
result_df = pd.DataFrame({
    'Date': df_new['Date'],
    'Actual': df_new['Close'],
    'Predicted': predictions.flatten()
})

# print the Date, Actual Price, and Predicted Price
for date, actual, predicted in zip(result_df['Date'], result_df['Actual'], result_df['Predicted']):
   print(f'Date: {date} | Actual Closing Price: {actual:.2f} | Predicted Closing Price: {predicted:.2f}')

# calculating the Mean Squared Error (MSE)
mse = ((result_df['Actual'] - result_df['Predicted']) ** 2).mean()

# calculating the Mean Absolute Error (MAE)
mae = abs(result_df['Actual'] - result_df['Predicted']).mean()

# printing the metrics
print(f'Model Trained with: {number_epochs} epoch(s)')
print(f'Mean Squared Error (MSE): {mse:.4f}')
print(f'Mean Absolute Error (MAE): {mae:.4f}')

# saving actual price and predicted data into CSV file for later use
result_df.to_csv(f'prediction_results_with_{number_epochs}_epochs.csv', index=False)
# Out:
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# Date: 2005-10-06 | Actual Closing Price: 7.79 | Predicted Closing Price: 8.11
# Date: 2005-10-07 | Actual Closing Price: 7.80 | Predicted Closing Price: 8.11
# Date: 2005-10-10 | Actual Closing Price: 7.74 | Predicted Closing Price: 8.05
# Date: 2005-10-11 | Actual Closing Price: 7.62 | Predicted Closing Price: 8.04
# Date: 2005-10-12 | Actual Closing Price: 7.50 | Predicted Closing Price: 7.93
# Date: 2005-10-13 | Actual Closing Price: 7.41 | Predicted Closing Price: 7.86
# Date: 2005-10-14 | Actual Closing Price: 7.38 | Predicted Closing Price: 7.78
# Date: 2005-10-17 | Actual Closing Price: 7.60 | Predicted Closing Price: 7.78
# Date: 2005-10-18 | Actual Closing Price: 7.55 | Predicted Closing Price: 7.90
# Date: 2005-10-19 | Actual Closing Price: 7.69 | Predicted Closing Price: 7.91
# Date: 2005-10-20 | Actual Closing Price: 7.55 | Predicted Closing Price: 8.10
# Date: 2005-10-21 | Actual Closing Price: 8.47 | Predicted Closing Price: 9.08
# Date: 2005-10-24 | Actual Closing Price: 8.68 | Predicted Closing Price: 8.85
# Date: 2005-10-25 | Actual Closing Price: 8.64 | Predicted Closing Price: 8.83
# Date: 2005-10-26 | Actual Closing Price: 8.85 | Predicted Closing Price: 8.94
# Date: 2005-10-27 | Actual Closing Price: 8.79 | Predicted Closing Price: 9.04
# Date: 2005-10-28 | Actual Closing Price: 8.92 | Predicted Closing Price: 9.06
# Date: 2005-10-31 | Actual Closing Price: 9.27 | Predicted Closing Price: 9.39
# Date: 2005-11-01 | Actual Closing Price: 9.45 | Predicted Closing Price: 9.68
# Date: 2005-11-02 | Actual Closing Price: 9.46 | Predicted Closing Price: 9.75
# Date: 2005-11-03 | Actual Closing Price: 9.61 | Predicted Closing Price: 9.73
# Date: 2005-11-04 | Actual Closing Price: 9.72 | Predicted Closing Price: 9.91
# Date: 2005-11-07 | Actual Closing Price: 9.84 | Predicted Closing Price: 10.06
# Date: 2005-11-08 | Actual Closing Price: 9.71 | Predicted Closing Price: 9.99
# Date: 2005-11-09 | Actual Closing Price: 9.44 | Predicted Closing Price: 9.84
# Date: 2005-11-10 | Actual Closing Price: 9.74 | Predicted Closing Price: 9.72
# Date: 2005-11-11 | Actual Closing Price: 9.72 | Predicted Closing Price: 9.99
# Date: 2005-11-14 | Actual Closing Price: 9.89 | Predicted Closing Price: 9.98
# Date: 2005-11-15 | Actual Closing Price: 9.78 | Predicted Closing Price: 10.02
# Date: 2005-11-16 | Actual Closing Price: 9.92 | Predicted Closing Price: 10.07
# Date: 2005-11-17 | Actual Closing Price: 10.05 | Predicted Closing Price: 10.21
# Date: 2005-11-18 | Actual Closing Price: 9.97 | Predicted Closing Price: 10.20
# Date: 2005-11-21 | Actual Closing Price: 10.20 | Predicted Closing Price: 10.22
# Date: 2005-11-22 | Actual Closing Price: 10.37 | Predicted Closing Price: 10.43
# Date: 2005-11-23 | Actual Closing Price: 10.53 | Predicted Closing Price: 10.64
# Date: 2005-11-25 | Actual Closing Price: 10.68 | Predicted Closing Price: 10.73
# Date: 2006-03-10 | Actual Closing Price: 8.41 | Predicted Closing Price: 8.96
# Date: 2006-03-13 | Actual Closing Price: 8.40 | Predicted Closing Price: 8.85
# Date: 2006-03-14 | Actual Closing Price: 8.75 | Predicted Closing Price: 8.92
# Date: 2006-03-15 | Actual Closing Price: 8.58 | Predicted Closing Price: 9.03
# Date: 2006-03-16 | Actual Closing Price: 8.44 | Predicted Closing Price: 8.91
# Date: 2006-03-17 | Actual Closing Price: 8.46 | Predicted Closing Price: 8.70
# Date: 2006-03-20 | Actual Closing Price: 8.67 | Predicted Closing Price: 8.86
# Date: 2006-03-21 | Actual Closing Price: 8.47 | Predicted Closing Price: 8.95
# Date: 2006-03-22 | Actual Closing Price: 8.47 | Predicted Closing Price: 8.72
# Date: 2006-03-23 | Actual Closing Price: 8.52 | Predicted Closing Price: 8.77
# Date: 2006-03-24 | Actual Closing Price: 9.11 | Predicted Closing Price: 9.50
# Date: 2006-03-27 | Actual Closing Price: 9.21 | Predicted Closing Price: 9.36
# Date: 2006-03-28 | Actual Closing Price: 9.39 | Predicted Closing Price: 9.52
# Date: 2006-03-29 | Actual Closing Price: 9.84 | Predicted Closing Price: 9.98
# Date: 2006-03-30 | Actual Closing Price: 9.67 | Predicted Closing Price: 10.01
# Date: 2006-03-31 | Actual Closing Price: 9.71 | Predicted Closing Price: 10.39
# Date: 2006-04-03 | Actual Closing Price: 9.71 | Predicted Closing Price: 9.90
# Date: 2006-04-04 | Actual Closing Price: 10.07 | Predicted Closing Price: 10.13
# Date: 2006-04-05 | Actual Closing Price: 10.16 | Predicted Closing Price: 10.46
# Date: 2006-04-06 | Actual Closing Price: 10.24 | Predicted Closing Price: 10.35
# Date: 2006-04-07 | Actual Closing Price: 10.12 | Predicted Closing Price: 10.40
# Date: 2006-04-10 | Actual Closing Price: 10.37 | Predicted Closing Price: 10.40
# Date: 2006-04-11 | Actual Closing Price: 10.20 | Predicted Closing Price: 10.58
# Date: 2006-04-12 | Actual Closing Price: 10.19 | Predicted Closing Price: 10.33
# Date: 2006-04-13 | Actual Closing Price: 10.02 | Predicted Closing Price: 10.30
# Date: 2006-04-17 | Actual Closing Price: 10.13 | Predicted Closing Price: 10.28
# Date: 2006-04-18 | Actual Closing Price: 10.07 | Predicted Closing Price: 10.33
# Date: 2006-04-19 | Actual Closing Price: 10.22 | Predicted Closing Price: 10.41
# Date: 2006-04-20 | Actual Closing Price: 10.34 | Predicted Closing Price: 10.51
# Date: 2006-04-21 | Actual Closing Price: 10.89 | Predicted Closing Price: 11.58
# Date: 2006-04-24 | Actual Closing Price: 10.97 | Predicted Closing Price: 11.15
# Date: 2006-04-25 | Actual Closing Price: 10.64 | Predicted Closing Price: 11.10
# Date: 2006-04-26 | Actual Closing Price: 10.61 | Predicted Closing Price: 10.80
# Date: 2006-04-27 | Actual Closing Price: 10.46 | Predicted Closing Price: 10.72
# Date: 2006-04-28 | Actual Closing Price: 10.41 | Predicted Closing Price: 10.62
# Date: 2006-05-01 | Actual Closing Price: 9.94 | Predicted Closing Price: 10.57
# Date: 2006-10-02 | Actual Closing Price: 10.00 | Predicted Closing Price: 10.13
# Date: 2006-10-03 | Actual Closing Price: 10.06 | Predicted Closing Price: 10.15
# Date: 2006-10-04 | Actual Closing Price: 10.35 | Predicted Closing Price: 10.31
# Date: 2006-10-05 | Actual Closing Price: 10.26 | Predicted Closing Price: 10.47
# Date: 2006-10-06 | Actual Closing Price: 10.47 | Predicted Closing Price: 10.45
# Date: 2006-10-09 | Actual Closing Price: 10.68 | Predicted Closing Price: 10.78
# Date: 2006-10-10 | Actual Closing Price: 10.63 | Predicted Closing Price: 10.95
# Date: 2006-10-11 | Actual Closing Price: 10.62 | Predicted Closing Price: 10.73
# Date: 2006-10-12 | Actual Closing Price: 10.65 | Predicted Closing Price: 10.77
# Date: 2006-10-13 | Actual Closing Price: 10.64 | Predicted Closing Price: 10.74
# Date: 2006-10-16 | Actual Closing Price: 10.50 | Predicted Closing Price: 10.74
# Date: 2006-10-17 | Actual Closing Price: 10.48 | Predicted Closing Price: 10.59
# Date: 2006-10-18 | Actual Closing Price: 10.44 | Predicted Closing Price: 10.66
# Date: 2006-10-19 | Actual Closing Price: 10.61 | Predicted Closing Price: 10.76
# Date: 2006-10-20 | Actual Closing Price: 11.45 | Predicted Closing Price: 11.65
# Date: 2006-10-23 | Actual Closing Price: 11.97 | Predicted Closing Price: 11.96
# Date: 2006-10-24 | Actual Closing Price: 11.79 | Predicted Closing Price: 12.03
# Date: 2006-10-25 | Actual Closing Price: 12.12 | Predicted Closing Price: 12.15
# Date: 2006-10-26 | Actual Closing Price: 12.08 | Predicted Closing Price: 12.31
# Date: 2006-10-27 | Actual Closing Price: 11.84 | Predicted Closing Price: 12.16
# Date: 2006-10-30 | Actual Closing Price: 11.87 | Predicted Closing Price: 11.98
# Date: 2006-10-31 | Actual Closing Price: 11.87 | Predicted Closing Price: 12.05
# Date: 2006-11-01 | Actual Closing Price: 11.64 | Predicted Closing Price: 11.99
# Date: 2006-11-02 | Actual Closing Price: 11.70 | Predicted Closing Price: 11.79
# Date: 2006-11-03 | Actual Closing Price: 11.75 | Predicted Closing Price: 11.85
# Date: 2006-11-06 | Actual Closing Price: 11.88 | Predicted Closing Price: 11.94
# Date: 2006-11-07 | Actual Closing Price: 11.77 | Predicted Closing Price: 11.98
# Date: 2006-11-08 | Actual Closing Price: 11.83 | Predicted Closing Price: 11.94
# Date: 2006-11-09 | Actual Closing Price: 11.77 | Predicted Closing Price: 11.97
# Date: 2006-11-10 | Actual Closing Price: 11.79 | Predicted Closing Price: 11.86
# Date: 2006-11-13 | Actual Closing Price: 11.98 | Predicted Closing Price: 11.96
# Date: 2006-11-14 | Actual Closing Price: 12.19 | Predicted Closing Price: 12.18
# Date: 2006-11-15 | Actual Closing Price: 12.25 | Predicted Closing Price: 12.50
# Date: 2006-11-16 | Actual Closing Price: 12.35 | Predicted Closing Price: 12.45
# Date: 2006-11-17 | Actual Closing Price: 12.42 | Predicted Closing Price: 12.45
# Date: 2024-01-18 | Actual Closing Price: 144.99 | Predicted Closing Price: 143.99
# Date: 2024-01-19 | Actual Closing Price: 147.97 | Predicted Closing Price: 146.75
# Date: 2024-01-22 | Actual Closing Price: 147.71 | Predicted Closing Price: 148.94
# Date: 2024-01-23 | Actual Closing Price: 148.68 | Predicted Closing Price: 148.02
# Date: 2024-01-24 | Actual Closing Price: 150.35 | Predicted Closing Price: 150.65
# Date: 2024-01-25 | Actual Closing Price: 153.64 | Predicted Closing Price: 152.63
# Date: 2024-01-26 | Actual Closing Price: 153.79 | Predicted Closing Price: 153.36
# Date: 2024-01-29 | Actual Closing Price: 154.84 | Predicted Closing Price: 154.18
# Date: 2024-01-30 | Actual Closing Price: 153.05 | Predicted Closing Price: 154.32
# Date: 2024-01-31 | Actual Closing Price: 141.80 | Predicted Closing Price: 144.96
# Date: 2024-02-01 | Actual Closing Price: 142.71 | Predicted Closing Price: 143.73
# Date: 2024-02-02 | Actual Closing Price: 143.54 | Predicted Closing Price: 141.43
# Date: 2024-02-05 | Actual Closing Price: 144.93 | Predicted Closing Price: 144.69
# Date: 2024-02-06 | Actual Closing Price: 145.41 | Predicted Closing Price: 146.00
# Date: 2024-02-07 | Actual Closing Price: 146.68 | Predicted Closing Price: 146.28
# Date: 2024-02-08 | Actual Closing Price: 147.22 | Predicted Closing Price: 147.10
# Date: 2024-02-09 | Actual Closing Price: 150.22 | Predicted Closing Price: 148.69
# Date: 2024-02-12 | Actual Closing Price: 148.73 | Predicted Closing Price: 149.75
# Date: 2024-02-13 | Actual Closing Price: 146.37 | Predicted Closing Price: 146.48
# Date: 2024-02-14 | Actual Closing Price: 147.14 | Predicted Closing Price: 147.33
# Date: 2024-02-15 | Actual Closing Price: 143.94 | Predicted Closing Price: 144.27
# Date: 2024-02-16 | Actual Closing Price: 141.76 | Predicted Closing Price: 143.93
# Date: 2024-02-20 | Actual Closing Price: 142.20 | Predicted Closing Price: 141.52
# Date: 2024-02-21 | Actual Closing Price: 143.84 | Predicted Closing Price: 142.92
# Date: 2024-02-22 | Actual Closing Price: 145.32 | Predicted Closing Price: 145.92
# Date: 2024-02-23 | Actual Closing Price: 145.29 | Predicted Closing Price: 145.20
# Model Trained with: 100 epoch(s)
# Mean Squared Error (MSE): 0.5246
# Mean Absolute Error (MAE): 0.4594

# %% [markdown]
# ##  Third
#
# 1. Getting predicted result from previously saved CSV file
# 2. Plotting the data into bokeh plotting (bokeh plotting giving better look than matlab)

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import HoverTool, ColumnDataSource

# setting epochs
number_epochs = 100

# loading the CSV file based on number of epochs into a DataFrame
df = pd.read_csv(f'prediction_results_with_{number_epochs}_epochs.csv')

# Create a Bokeh figure
p = figure(x_axis_label='Date', y_axis_label='Price', title='Actual vs Predicted Prices', x_range=df['Date'].astype(str).tolist(), height=500, width=900)

# Create a ColumnDataSource
source = ColumnDataSource(df)

# Plot actual prices as bars
p.vbar(x='Date', top='Actual', width=0.5, source=source, legend_label='Actual Price', color='green')

# Plot predicted prices as a line
p.line(x='Date', y='Predicted', source=source, legend_label='Predicted Price', line_width=2, line_color='blue')

# Add hover tool
hover = HoverTool()
hover.tooltips = [('Date', '@Date{%F}'), ('Actual Price', '@Actual'), ('Predicted Price', '@Predicted')]
hover.formatters = {'@Date': 'datetime'}
p.add_tools(hover)

# Customize the plot layout
p.legend.location = 'top_left'
p.legend.click_policy = 'hide'

# Output to notebook
output_notebook()

# Display the plot in the notebook
show(p, notebook_handle=True)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="fcc6fded-a5a6-4eb8-8be4-1687292a2197">Loading BokehJS ...</span>
#     </div>
#   <div id="b91ef077-7470-425f-a0b2-e06471082ff5" data-root-id="p1001" style="display: contents;"></div>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[3]</strong>&gt;</code></p>

# %% [markdown]
# ## Fourth
# 1. Loading historical data again
# 2. Loading saved model
# 3. Based on last available data recursively predicting closing price until I can predict the closing price for selected date

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import load_model
import pickle

def generate_data_for_date(date, scaler, historical_data, num_days=10):
    # Create a DataFrame with zeros and the specified date
    new_data = pd.DataFrame(index=[0], columns=['Open', 'High', 'Low', 'Close', 'Volume', 'Date'])
    new_data['Date'] = date

    try:
        # Find the rows corresponding to the specified date in the historical data
        selected_data = historical_data[historical_data['Date'] == pd.to_datetime(date)]
        
        if not selected_data.empty:
            # Use the selected data as input features
            selected_data = selected_data.iloc[0]
            new_data[['Open', 'High', 'Low', 'Close', 'Volume']] = selected_data[['Open', 'High', 'Low', 'Close', 'Volume']].values
        else:
            raise ValueError("No data found for the specified date.")
    except ValueError as e:
        # error occurred becasue no date found in the csv for the date
        # selecting the last num_days rows before the specified date
        selected_data = historical_data.iloc[-num_days:]

        # calculating the average of the selected data
        average_data = selected_data.mean()

        # using the calculated average as input features
        new_data[['Open', 'High', 'Low', 'Close', 'Volume']] = average_data[['Open', 'High', 'Low', 'Close', 'Volume']].values

    # scaling the features using the pre-trained scaler
    scaled_features = scaler.transform(new_data[['Open', 'High', 'Low', 'Close', 'Volume']])

    # assigning scaled features back to new_data
    new_data[['Open', 'High', 'Low', 'Close', 'Volume']] = scaled_features

    return new_data

# number of epochs
number_epochs = 100

# loading the pre-trained model
model = load_model(f'stock_price_prediction_model_5000_epochs.keras')

# loading the pre-trained scaler
with open(f'scaler_{number_epochs}_epochs.pkl', 'rb') as f:
    scaler = pickle.load(f)

# loading historical data
historical_data = pd.read_csv('GOOG.csv')
historical_data['Date'] = pd.to_datetime(historical_data['Date'])

# ensuring data is sorted by date
historical_data = historical_data.sort_values(by='Date')

# specifying the date for which I want to generate predictions
specific_date = '2024-02-10'

# generating data for the specific date using the average of the last 10 days
input_data = generate_data_for_date(specific_date, scaler, historical_data, num_days=10)

# printing the generated input data
# print(f"Input Data for {specific_date}:")
# print(input_data)

# reshaping the input data for LSTM input and cast to float32
input_data_lstm = input_data[['Open', 'High', 'Low', 'Close', 'Volume']].values.reshape((1, 5, 1)).astype('float32')

# making predictions using the pre-trained model
predicted_close = model.predict(input_data_lstm)[0][0]

# printing the predicted close price
print(f'Predicted Close Price for {specific_date}: {predicted_close}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# Predicted Close Price for 2024-02-10: 145.25819396972656
